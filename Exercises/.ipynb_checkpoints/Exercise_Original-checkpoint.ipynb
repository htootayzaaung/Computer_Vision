# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from imutils.perspective import four_point_transform

# %%
def show_images(titles, images, wait=True):
    """Display multiple images with one line of code"""

    for (title, image) in zip(titles, images):
        plt.title(title)
        plt.imshow(image)
        plt.axis("off")
        plt.show()

    if wait:
        cv2.waitKey(0)
        cv2.destroyAllWindows()

# %%
height = 800
width = 600
green = (0, 255, 0) # green color
red = (0, 0, 255) # red color
white = (255, 255, 255) # white color
questions = 5
answers = 5
correct_ans = [0, 2, 1, 3, 4]

img = cv2.imread('1.jpg')
img = cv2.resize(img, (width, height))

img2 = cv2.imread('2.jpg')
img2 = cv2.resize(img2, (width, height))

img3 = cv2.imread('3.jpg')
img3 = cv2.resize(img2, (width, height))

img4 = cv2.imread('4.jpg')
img4 = cv2.resize(img4, (width, height))

img_copy = img.copy() # for display purposes
img_copy1 = img.copy() # for display purposes
img_copy2 = img2.copy()
img_copy3 = img3.copy()
img_copy4 = img4.copy()

gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray_img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
gray_img4 = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)

blur_img = cv2.GaussianBlur(gray_img, (5, 5), 0)
blur_img2 = cv2.GaussianBlur(gray_img2, (5, 5), 0)
blur_img3 = cv2.GaussianBlur(gray_img3, (5, 5), 0)
blur_img4 = cv2.GaussianBlur(gray_img4, (5, 5), 0)

edge_img = cv2.Canny(blur_img, 20, 200) # adjust with your images
edge_img2 = cv2.Canny(blur_img2, 20, 200) # adjust with your images
edge_img3 = cv2.Canny(blur_img3, 20, 200) # adjust with your images
edge_img4 = cv2.Canny(blur_img4, 20, 200) # adjust with your images

# find the contours in the image
contours, _ = cv2.findContours(edge_img, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
contours2, _ = cv2.findContours(edge_img2, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
contours3, _ = cv2.findContours(edge_img3, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
contours4, _ = cv2.findContours(edge_img4, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

# draw the contours
cv2.drawContours(img, contours, -1, green, 3)
cv2.drawContours(img2, contours2, -1, green, 3)
cv2.drawContours(img3, contours3, -1, green, 3)
cv2.drawContours(img4, contours4, -1, green, 3)

show_images(['image'], [img]) # helper function in helper.py file
show_images(['image2'], [img2])
show_images(['image3'], [img3])
show_images(['image4'], [img4])

# %%
def get_rect_cnts(contours):
    rect_cnts = []
    for cnt in contours:
        # approximate the contour
        peri = cv2.arcLength(cnt, True)
        approx = cv2.approxPolyDP(cnt, 0.02 * peri, True)
        # if the approximated contour is a rectangle ...
        if len(approx) == 4:
            # append it to our list
            rect_cnts.append(approx)
    # sort the contours from biggest to smallest
    rect_cnts = sorted(rect_cnts, key=cv2.contourArea, reverse=True)

    return rect_cnts

# %%
rect_cnts = get_rect_cnts(contours)
# warp perspective to get the top-down view of the document
document = four_point_transform(img_copy, rect_cnts[0].reshape(4, 2))
document2 = four_point_transform(img_copy2, rect_cnts[0].reshape(4, 2))
document3 = four_point_transform(img_copy3, rect_cnts[0].reshape(4, 2))
document4 = four_point_transform(img_copy4, rect_cnts[0].reshape(4, 2))

doc_copy = document.copy()  # for display purposes
doc_copy1 = document.copy() # for display purposes
doc_copy2 = document2.copy()
doc_copy3 = document3.copy()
doc_copy4 = document4.copy()

cv2.drawContours(img_copy, rect_cnts, -1, green, 3)
cv2.drawContours(img_copy2, rect_cnts, -1, green, 3)
cv2.drawContours(img_copy3, rect_cnts, -1, green, 3)
cv2.drawContours(img_copy4, rect_cnts, -1, green, 3)

# helper function in helper.py file
show_images(['image', 'document'], [img_copy, document])
show_images(['image2', 'document'], [img_copy2, document2])
show_images(['image3', 'document'], [img_copy3, document3])
show_images(['image4', 'document'], [img_copy4, document4])

# %%
########################################################################
# Find the Two Biggest Contours on the Document
########################################################################

# find contours on the document
gray_doc = cv2.cvtColor(document, cv2.COLOR_BGR2GRAY)
gray_doc2 = cv2.cvtColor(document2, cv2.COLOR_BGR2GRAY)
gray_doc3 = cv2.cvtColor(document3, cv2.COLOR_BGR2GRAY)
gray_doc4 = cv2.cvtColor(document4, cv2.COLOR_BGR2GRAY)

blur_doc = cv2.GaussianBlur(gray_doc, (3, 3), 0)
blur_doc2 = cv2.GaussianBlur(gray_doc2, (3, 3), 0)
blur_doc3 = cv2.GaussianBlur(gray_doc3, (3, 3), 0)
blur_doc4 = cv2.GaussianBlur(gray_doc4, (3, 3), 0)

edge_doc = cv2.Canny(blur_doc, 10, 70)
edge_doc2 = cv2.Canny(blur_doc2, 10, 70)
edge_doc3 = cv2.Canny(blur_doc3, 10, 70)
edge_doc4 = cv2.Canny(blur_doc4, 10, 70)

show_images(['edge image'], [edge_doc])
show_images(['edge image2'], [edge_doc2])
show_images(['edge image3'], [edge_doc3])
show_images(['edge image4'], [edge_doc4])

contours, _ = cv2.findContours(edge_doc, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
contours2, _ = cv2.findContours(edge_doc2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
contours3, _ = cv2.findContours(edge_doc3, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
contours4, _ = cv2.findContours(edge_doc4, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)


rect_cnts = get_rect_cnts(contours)
print(rect_cnts)
# contours of the questions
biggest_cnt = rect_cnts[0]
# contours of the grade
grade_cnt = rect_cnts[1]

# draw the two biggest contours, which are the
# contour of the questions and the contour of the grade
cv2.drawContours(document, rect_cnts[:2], -1, green, 3)
cv2.drawContours(document2, rect_cnts[:2], -1, green, 3)
cv2.drawContours(document3, rect_cnts[:2], -1, green, 3)
cv2.drawContours(document4, rect_cnts[:2], -1, green, 3)

show_images(['two biggest contours'], [document])
show_images(['two biggest contours2'], [document2])
show_images(['two biggest contours3'], [document3])
show_images(['two biggest contours4'], [document4])
# Out:
# [array([[[476,   6]],
#
#        [[  6,   9]],
#
#        [[  7, 661]],
#
#        [[477, 662]]], dtype=int32)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 37
#      35 biggest_cnt = rect_cnts[0]
#      36 # contours of the grade
# ---> 37 grade_cnt = rect_cnts[1]
#      39 # draw the two biggest contours, which are the
#      40 # contour of the questions and the contour of the grade
#      41 cv2.drawContours(document, rect_cnts[:2], -1, green, 3)
#
# IndexError: list index out of range

# %%
########################################################################
# Mask Everything in the Document Except the Area of the Biggest Contour
########################################################################

# cooredinates of the biggest contour
# I added 4 pixels to x and y, and removed 4 pixels from x_W and y_H to make
# sure we are inside the contour and not take the border of the biggest contour
x, y = biggest_cnt[0][0][0] + 4, biggest_cnt[0][0][1] + 4
x_W, y_H = biggest_cnt[2][0][0] - 4, biggest_cnt[2][0][1] - 4

# create a black image with the same dimension as the document
mask =  np.zeros((document.shape[0], document.shape[1]), np.uint8)
# we create a white rectangle in the region of the biggest contour
cv2.rectangle(mask, (x, y), (x_W, y_H), white, -1)
masked = cv2.bitwise_and(doc_copy, doc_copy, mask=mask)

show_images(['document', 'mask', 'masked'], [doc_copy, mask, masked])

# take only the region of the biggest contour
masked = masked[y:y_H, x:x_W]
print(masked)
gray = cv2.cvtColor(masked, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY_INV)

show_images(['masked', 'thresh'], [masked, thresh])
# Out:
# [[[217 217 217]
#   [216 218 218]
#   [215 217 217]
#   ...
#   [137 136 136]
#   [142 142 142]
#   [132 132 132]]
#
#  [[218 217 218]
#   [217 215 216]
#   [215 217 217]
#   ...
#   [179 179 179]
#   [175 175 175]
#   [183 183 183]]
#
#  [[219 219 219]
#   [220 219 219]
#   [216 218 218]
#   ...
#   [216 217 217]
#   [213 215 215]
#   [216 218 218]]
#
#  ...
#
#  [[212 212 212]
#   [212 212 212]
#   [213 213 213]
#   ...
#   [219 219 219]
#   [220 220 220]
#   [220 220 220]]
#
#  [[213 213 213]
#   [211 211 211]
#   [212 212 212]
#   ...
#   [218 218 218]
#   [219 219 219]
#   [219 219 219]]
#
#  [[208 208 208]
#   [211 211 211]
#   [212 212 212]
#   ...
#   [218 218 218]
#   [219 219 219]
#   [221 221 221]]]

# %%
########################################################################
# Split the Area of the Biggest Contour
########################################################################

# split the thresholded image into boxes
def split_image(image):
    # make the number of rows and columns
    # a multiple of 5 (questions = answers = 5)
    r = len(image) // questions * questions
    c = len(image[0]) // answers * answers
    image = image[:r, :c]
    # split the image horizontally (row-wise)
    rows = np.vsplit(image, questions)
    boxes = []
    for row in rows:
        # split each row vertically (column-wise)
        cols = np.hsplit(row, answers)
        for box in cols:
            boxes.append(box)
    return boxes

boxes = split_image(thresh)

# %%
########################################################################
# Start Grading the Document
########################################################################

score = 0

# loop over the questions
for i in range(0, questions):
    user_answer = None

    # loop over the answers
    for j in range(answers):
        pixels = cv2.countNonZero(boxes[j + i * 5])
        # if the current answer has a larger number of
        # non-zero (white) pixels then the previous one
        # we update the `user_answer` variable
        if user_answer is None or pixels > user_answer[1]:
            user_answer = (j, pixels)

    # find the contours of the bubble that the user has filled
    cnt, _ = cv2.findContours(boxes[user_answer[0] + i * 5],
                                      cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    # translate the coordinates of the contours
    # to their original place in the document
    for c in cnt:
        c[:, :, 0] += x + ((x_W - x) // 5) * user_answer[0]
        c[:, :, 1] += y + ((y_H - y) // 5) * i


    # if the user's answer is correct, we increase the score and draw
    # a green contour arround the bubble that the user has filled
    if correct_ans[i] == user_answer[0]:
        cv2.drawContours(doc_copy1, cnt, -1, [0,255,0], 3)
        cv2.drawContours(doc_copy2, cnt, -1, [0,255,0], 3)
        score += 1
    # otherwise we draw a red contour
    else:
        cv2.drawContours(doc_copy1, cnt, -1, [255,0,0], 3)
        cv2.drawContours(doc_copy2, cnt, -1, [255,0,0], 3)


score = (score / 5) * 100

# get the (x, y) coordinates of the grade contour.
# we add some pixels to make sure the text is inside the contour.
x_grade = grade_cnt[0][0][0] + 15
y_grade = grade_cnt[0][0][1] + 45
x_grade2 = grade_cnt[0][0][0] + 15
y_grade2 = grade_cnt[0][0][1] + 45

cv2.putText(doc_copy1, "{}%".format(int(score)),
            (x_grade, y_grade), cv2.FONT_HERSHEY_SIMPLEX, 0.9, [255,0,0], 3)

cv2.putText(doc_copy2, "{}%".format(int(score)),
            (x_grade2, y_grade2), cv2.FONT_HERSHEY_SIMPLEX, 0.9, [255,0,0], 3)

show_images(['image', 'final score'], [img_copy1, doc_copy1])
show_images(['image2', 'final score2'], [img_copy2, doc_copy2])
