# %% [markdown]
# **Read, Show and Write an Image**

# %% [markdown]
# The python libraries cv2 needed to be imported before reading an image.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read image as gray scale.

cb_img = cv2.imread("/content/download.jpg")

# Print the image data (pixel values), element of a 2D numpy array.
# Each pixel value is 8-bits [0,255]

#print(cb_img)

# %%
cb_img[:,:,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cb_img[:,:,2]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# print the size  of image
print("Image size is ", cb_img.shape)

# print data-type of image
print("Data type of image is ", cb_img.dtype)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # print the size  of image
# ----> 2 print("Image size is ", cb_img.shape)
#       4 # print data-type of image
#       5 print("Data type of image is ", cb_img.dtype)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
plt.imshow(cb_img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.imshow(cb_img)
#
# File /usr/lib/python3/dist-packages/matplotlib/_api/deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2640, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2634 @_copy_docstring_and_deprecators(Axes.imshow)
#    2635 def imshow(
#    2636         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2637         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2638         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2639         resample=None, url=None, data=None, **kwargs):
# -> 2640     __ret = gca().imshow(
#    2641         X, cmap=cmap, norm=norm, aspect=aspect,
#    2642         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2643         vmax=vmax, origin=origin, extent=extent,
#    2644         interpolation_stage=interpolation_stage,
#    2645         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2646         url=url, **({"data": data} if data is not None else {}),
#    2647         **kwargs)
#    2648     sci(__ret)
#    2649     return __ret
#
# File /usr/lib/python3/dist-packages/matplotlib/_api/deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:1416, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1413 @functools.wraps(func)
#    1414 def inner(ax, *args, data=None, **kwargs):
#    1415     if data is None:
# -> 1416         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1418     bound = new_sig.bind(ax, *args, **kwargs)
#    1419     auto_label = (bound.arguments.get(label_namer)
#    1420                   or bound.kwargs.get(label_namer))
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:5488, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5481 self.set_aspect(aspect)
#    5482 im = mimage.AxesImage(self, cmap, norm, interpolation,
#    5483                       origin, extent, filternorm=filternorm,
#    5484                       filterrad=filterrad, resample=resample,
#    5485                       interpolation_stage=interpolation_stage,
#    5486                       **kwargs)
# -> 5488 im.set_data(X)
#    5489 im.set_alpha(alpha)
#    5490 if im.get_clip_path() is None:
#    5491     # image does not already have clipping set, clip to axes patch
#
# File /usr/lib/python3/dist-packages/matplotlib/image.py:706, in _ImageBase.set_data(self, A)
#     702 self._A = cbook.safe_masked_invalid(A, copy=True)
#     704 if (self._A.dtype != np.uint8 and
#     705         not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 706     raise TypeError("Image data of dtype {} cannot be converted to "
#     707                     "float".format(self._A.dtype))
#     709 if self._A.ndim == 3 and self._A.shape[-1] == 1:
#     710     # If just one dimension assume scalar and apply colormap
#     711     self._A = self._A[:, :, 0]
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
import cv2
# !wget "https://cdn.pixabay.com/photo/2021/02/12/02/01/rosebud-6006985_1280.jpg"
# Out:
# --2023-03-25 09:48:47--  https://cdn.pixabay.com/photo/2021/02/12/02/01/rosebud-6006985_1280.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.14.16, 104.18.15.16, 2606:4700::6812:f10, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.14.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 145013 (142K) [binary/octet-stream]
# Saving to: ‘rosebud-6006985_1280.jpg’
#
# rosebud-6006985_128 100%[===================>] 141.61K  --.-KB/s    in 0.02s
#
# 2023-03-25 09:48:47 (8.48 MB/s) - ‘rosebud-6006985_1280.jpg’ saved [145013/145013]

# %%
img_color = cv2.imread('/content/download.jpg',1)
img_grayscale = cv2.imread('/content/download.jpg',0)
img_unchanged = cv2.imread('/content/download.jpg',-1)

# %%
from matplotlib import pyplot as plt

# %%
image_color=cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_color)
plt.axis("off")
plt.show()
img_color.size
# Out:
# 151335

# %%
plt.imshow(img_grayscale)
plt.axis("off")
plt.show()

# %%
plt.imshow(img_unchanged)
plt.axis("off")
plt.show()

# %%
img_color[:,:,0]=0
img_color[:,:,1]=255
img_color[:,:,2]=0
plt.imshow(img_color)

# %%
img_color [:,:,1] = 0
img_color [:,:,2] = 0
img_color_red = img_color[:, ::1,: ]

img_color_red
plt.imshow(img_color_red)

# %%
[b,g,r]= img_color[100,180]
b
g
r
# Out:
# 0

# %%
img_color_green = img_color[:, ::1, :]

img_color_green
plt.imshow(img_color_green)

# %%
img_color_blue = img_color[::1, :, :]

img_color_blue
plt.imshow(img_color_blue)

# %%
plt.axis("off")
plt.imshow(cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(img_grayscale, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
plt.imshow(cv2.cvtColor(img_unchanged, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
cv2.imwrite("test_flower.png", img_grayscale)

from IPython.display import Image
Image(filename='test_flower.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6cd8caeedf9> in <module>()
# ----> 1 cv2.imwrite("test_flower.png", img_grayscale)
#       2
#       3 from IPython.display import Image
#       4 Image(filename='test_flower.png')
#
# NameError: name 'cv2' is not defined

# %%
cv2.imwrite("test_flower.png", img_grayscale_nxt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-5dbe7afbc460> in <module>
# ----> 1 cv2.imwrite("test_flower.png", img_grayscale_nxt)
#
# NameError: name 'img_grayscale_nxt' is not defined
